# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in preprocessed data

# %%
pagelookup_df = pd.read_csv("outputs/pagelookup_df.csv")
pagelookup_df
# Out:
#          ReversedDomain                                 URL  \
# 0             ac.accent               http://www.accent.ac/
# 1                ac.acs                  http://www.acs.ac/
# 2             ac.aikido  http://aikido.ac/langnau/index.php
# 3               ac.apec                 http://www.apec.ac/
# 4                ac.apt                  http://www.apt.ac/
# ...                 ...                                 ...
# 1808224       zw.co.zol               http://www.zol.co.zw/
# 1808225  zw.gov.parlzim          http://www.parlzim.gov.zw/
# 1808226      zw.org.csz              http://www.csz.org.zw/
# 1808227   zw.org.nascoh           http://www.nascoh.org.zw/
# 1808228     zw.org.zlhr             http://www.zlhr.org.zw/
#
#                                                      Title  \
# 0                                          Accent Services
# 1                                  Anderson County Schools
# 2                                   Langnau - Aikidogruppe
# 3                                                     APEC
# 4              The Association for Psychological Therapies
# ...                                                    ...
# 1808224                                    Zimbabwe Online
# 1808225                                Zimbabwe Parliament
# 1808226                       Computer Society of Zimbabwe
# 1808227  National Association of Societies for the Care...
# 1808228           Zimbabwe Lawyers for Human Rights (ZLHR)
#
#                                                Description        ID
# 0        UK based full service commercial / industrial ...       362
# 1        K-12 public schools in the county (not includi...       383
# 2        Einführungskurse in Zusammenarbeit mit der Vol...       424
# 3        Birmingham practice provides information on co...       536
# 4        An independent organization offering accredite...       548
# ...                                                    ...       ...
# 1808224                                       Dial-up ISP.  91033670
# 1808225  Provides current Bills, order paper, Hansard t...  91033765
# 1808226  Aims to encourage research and development in ...  91033860
# 1808227  The umbrella body for organisations of and for...  91033952
# 1808228  Non-profit organisation focusing on promoting ...  91034088
#
# [1808229 rows x 5 columns]

# %%
cleaned_df = pd.read_csv("outputs/cleaned_matched_df.csv")
cleaned_df
# Out:
#          ReversedDomain                                            Content  \
# 0             ac.accent  accent services uk based full service commerci...
# 1             ac.accent  accent services a full service commercial and ...
# 2                ac.acs  anderson county schools public schools in the ...
# 3             ac.aikido  langnau aikidogruppe in zusammenarbeit mit der...
# 4               ac.apec  apec birmingham practice provides information ...
# ...                 ...                                                ...
# 1888976  zw.gov.parlzim  zimbabwe parliament provides current bills ord...
# 1888977      zw.org.csz  computer society of zimbabwe aims to encourage...
# 1888978   zw.org.nascoh  national association of societies for the care...
# 1888979     zw.org.zlhr  zimbabwe lawyers for human rights zlhr non-pro...
# 1888980     zw.org.zlhr  zimbabwe lawyers for human rights zlhr non-pro...
#
#             Topic        ID
# 0        Business       362
# 1        Regional       362
# 2        Regional       383
# 3           World       424
# 4        Business       536
# ...           ...       ...
# 1888976  Regional  91033765
# 1888977  Regional  91033860
# 1888978   Society  91033952
# 1888979  Regional  91034088
# 1888980   Society  91034088
#
# [1888981 rows x 4 columns]

# %%
valid_nodes = cleaned_df["ID"].drop_duplicates().reset_index(drop=True)
valid_nodes
# Out:
# 0               362
# 1               383
# 2               424
# 3               536
# 4               548
#              ...
# 1808224    91033670
# 1808225    91033765
# 1808226    91033860
# 1808227    91033952
# 1808228    91034088
# Name: ID, Length: 1808229, dtype: int64

# %%
topics = cleaned_df["Topic"].unique()
topics
# Out:
# array(['Business', 'Regional', 'World', 'Health', 'Science', 'Sports',
#        'Society', 'Arts', 'Computers', 'Recreation', 'Shopping',
#        'Reference', 'Games', 'Home', 'News'], dtype=object)

# %%
term_vectors_df = pd.read_csv("outputs/term_vectors.csv")
term_vectors_df
# Out:
#                          Terms  Arts  Business  Computers  Games  Health  \
# 0                       accent    18        69          6      0       4
# 1                     services   556     24694       5796     80    5845
# 2                           uk  1352      4714        708    114     486
# 3                        based  3808     10849       2961    268    1071
# 4                         full   265      3095        408     42     636
# ...                        ...   ...       ...        ...    ...     ...
# 1198962  government-controlled     0         0          0      0       0
# 1198963               tanganda     0         0          0      0       0
# 1198964                 utande     0         0          0      0       0
# 1198965                 nascoh     0         0          0      0       0
# 1198966                   zlhr     0         0          0      0       0
#
#          Home  News  Recreation  Reference  Regional  Science  Shopping  \
# 0           0     0           1          2       113        2        33
# 1         294    77        1119        785    126547     2527       762
# 2         143    56         922        126      5788      594      1360
# 3         154   210        1910        264     10029      951      1384
# 4          30    12         644         92      9464      218       475
# ...       ...   ...         ...        ...       ...      ...       ...
# 1198962     0     0           0          0         1        0         0
# 1198963     0     0           0          0         1        0         0
# 1198964     0     0           0          0         1        0         0
# 1198965     0     0           0          0         0        0         0
# 1198966     0     0           0          0         1        0         0
#
#          Society  Sports  World
# 0              3       2     70
# 1           8888     653   8714
# 2            788     535     91
# 3           3024    1780    124
# 4            401     371    244
# ...          ...     ...    ...
# 1198962        0       0      0
# 1198963        0       0      0
# 1198964        0       0      0
# 1198965        1       0      0
# 1198966        1       0      0
#
# [1198967 rows x 16 columns]

# %%
term_vector_totals = term_vectors_df.drop(columns=["Terms"]).sum()
term_vector_totals
# Out:
# Arts           1026946
# Business       2673147
# Computers       639011
# Games           122926
# Health          484173
# Home            109627
# News             60290
# Recreation      818176
# Reference       243254
# Regional      10746814
# Science         452854
# Shopping        808629
# Society        1401758
# Sports          634039
# World         12130959
# dtype: int64

# %%
personal_vectors_df = pd.read_csv("outputs/personalization_vectors_df.csv")
personal_vectors_df
# Out:
#                ID  Arts  Business  Computers  Games    Health  Home  News  \
# 0             362   0.0  0.000007        0.0    0.0  0.000000   0.0   0.0
# 1             383   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 2             424   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 3             536   0.0  0.000007        0.0    0.0  0.000000   0.0   0.0
# 4             548   0.0  0.000000        0.0    0.0  0.000045   0.0   0.0
# ...           ...   ...       ...        ...    ...       ...   ...   ...
# 1808224  91033670   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 1808225  91033765   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 1808226  91033860   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 1808227  91033952   0.0  0.000000        0.0    0.0  0.000000   0.0   0.0
# 1808224   0.579432   1.089522  3.135899  0.708816  1.599988
# 1808225   0.931700   2.686489  0.955960  1.157622  1.705453
# 1808226   0.248161   0.353318  0.270418  0.227694  0.844889
# 1808227   0.000000   9.084542  0.000000  0.000000  0.420271
# 1808228  10.393023  19.575059  7.462938  4.101044  6.963520
#
# [1808229 rows x 17 columns]

# %% [markdown]
# # Query

# %%
def get_queried_rank(query):
    
    query_list = query.split(" ")
    query_rows = term_vectors_df[term_vectors_df['Terms'].isin(query_list)].drop(columns=['Terms'])

    # =           P(c_j)     * D_j_t1 * D_j_t2 * ... * D_j_tn   /   (Sum_i D_ji)    **    n
    weights = (1 / len(topics)) * query_rows.prod() / (term_vector_totals ** len(query_rows))
    weights = weights / weights.sum()
    
    ts_pagerank = (weights * pr_vectors_df.drop(columns=["ID", "Unbiased"])).sum(axis=1)
    
    return weights, ts_pagerank

# %%
def get_ranking(ts_pr):
    ranked_nodes = ts_pr.rename(index=valid_nodes).sort_values(ascending=False)
    ranked_df = pagelookup_df.set_index('ID').loc[ranked_nodes.index]
    
    return ranked_df

# %%
ts_pagerank
# Out:
# 0          5.372796e-09
# 1          1.682945e-07
# 2          3.883714e-10
# 3          3.060389e-09
# 4          7.143277e-09
#                ...
# 1808224    3.090619e-07
# 1808225    4.612963e-07
# 1808226    1.493460e-07
# 1808227    1.742240e-09
# 1808228    4.687004e-06
# Length: 1808229, dtype: float64

# %%
weights, ts_pagerank = get_queried_rank("chess")
# weights, ts_pagerank
results = get_ranking(ts_pagerank)
results
# Out:
#                        ReversedDomain                                  URL  \
# 77324560                     org.gmpg                 http://gmpg.org/xfn/
# 24402307                 com.gravatar             http://www.gravatar.com/
# 2532360                      be.youtu         https://youtu.be/p9jEL_LgAm4
# 61412448                       gl.goo                https://goo.gl/nTXC3f
# 42264752              com.statcounter          http://www.statcounter.com/
# ...                               ...                                  ...
# 21709718                 com.exer-fit             http://www.exer-fit.com/
# 36139673                com.par3tours                http://par3tours.com/
# 36139820          com.para-equestrian      http://www.para-equestrian.com/
# 12278458               com.audraerwin               http://audraerwin.com/
# 11182939  com.animalhospitalofchelsea  http://animalhospitalofchelsea.com/
#
#                                Title  \
# 77324560                         XFN
# 24402307                    Gravatar
# 2532360    Qu'est-ce qu'un mind map?
# 61412448          Giambiasi, Ludovic
# 42264752             StatCounter.com
# ...                              ...
# 21709718                    Exer-Fit
# 36139673          The Par 3 Tour LLC
# 36139820       Para Equestrian Rider
# 12278458                 Audra Erwin
# 11182939  Animal Hospital of Chelsea
#
#                                                 Description
# 77324560  XHTML Friends Network hyperlink protocol for b...
# 24402307  Lets weblogs and similar sites display user-pr...
# 2532360   Tony Buzan, l'inventeur de la méthode, présent...
# 61412448              Consultant formateur en informatique.
# 42264752  Detailed visitor statistics and a choice of gr...
# ...                                                     ...
# 21709718  Provides resources and expertise for planning ...
# 36139673  Results and information for events held only o...
# 36139820  Profile of Kathryn Wheelock, her horses, perfo...
# 12278458  A certified coach that specializes in fertilit...
# 11182939  Scott Simon D.V.M. offers a full service compa...
#
# [1808229 rows x 4 columns]

# %%
for t in cleaned_df.iloc[np.where(cleaned_df["ReversedDomain"]=="org.gmpg")]["Content"].str.split():
    print(t)
# Out:
# ['xfn', 'xhtml', 'friends', 'network', 'hyperlink', 'protocol', 'for', 'blogs', 'and', 'blogrolls']

# %%
results.head(30)
# Out:
#                   ReversedDomain  \
# 77324560                org.gmpg
# 2532360                 be.youtu
# 24402307            com.gravatar
# 61412448                  gl.goo
# 42264752         com.statcounter
# 42124715         com.squarespace
# 47938851               com.wufoo
# 14906471             com.brsgolf
# 43485988          com.technorati
# 78353324  org.networkadvertising
# 17933220        com.coursetrends
# 41564749             com.smugmug
# 78179073        org.microformats
# 35097510            com.nwsource
# 71235716           net.photomatt
# 88771059       uk.co.tripadvisor
# 43271453              com.tantek
# 42457342          com.stopdesign
# 9426850            com.accessify
# 35085914                 com.nvu
# 26383877            com.iamthedj
# 76385983         org.chrisjdavis
# 14650093            com.brainoff
# 34596735           com.nickfinck
# 77306602             org.glazman
# 32512987           com.metagrrrl
# 74007274            nl.netsensei
# 341785       ar.com.ultimorender
# 36973698        com.pixelcharmer
# 33611841           com.mullenweg
#
#                                                         URL  \
# 77324560                               http://gmpg.org/xfn/
# 2532360                        https://youtu.be/p9jEL_LgAm4
# 24402307                           http://www.gravatar.com/
# 61412448                              https://goo.gl/nTXC3f
# 42264752                        http://www.statcounter.com/
# 42124715                        http://www.squarespace.com/
# 47938851                                  http://wufoo.com/
# 14906471                            http://www.brsgolf.com/
# 43485988                         http://www.technorati.com/
# 78353324                 http://www.networkadvertising.org/
# 17933220  http://www.coursetrends.com/golf/proto/hiddenf...
# 41564749                            http://www.smugmug.com/
# 78179073                           http://microformats.org/
# 35097510                           http://www.nwsource.com/
# 71235716                              http://photomatt.net/
# 88771059  http://www.tripadvisor.co.uk/Tourism-g274723-P...
# 43271453                    http://tantek.com/CSS/Examples/
# 42457342                             http://stopdesign.com/
# 9426850                           http://www.accessify.com/
# 35085914                                http://www.nvu.com/
# 26383877                           http://www.iamthedj.com/
# 76385983                            http://chrisjdavis.org/
# 14650093       http://brainoff.com/weblog/outlines/myRadio/
# 34596735                          http://www.nickfinck.com/
# 77306602                     http://www.glazman.org/weblog/
# 32512987                          http://www.metagrrrl.com/
# 74007274                           http://www.netsensei.nl/
# 341785      http://ultimorender.com.ar/funkascript/perfora/
# 36973698                http://pixelcharmer.com/fieldnotes/
# 33611841                              http://mullenweg.com/
#
#                                           Title  \
# 77324560                                    XFN
# 2532360               Qu'est-ce qu'un mind map?
# 24402307                               Gravatar
# 61412448                     Giambiasi, Ludovic
# 42264752                        StatCounter.com
# 42124715                      Squarespace, Inc.
# 47938851                                  Wufoo
# 14906471                               BRS Golf
# 43485988                             Technorati
# 78353324         Network Advertising Initiative
# 17933220                 Hidden Falls Golf Club
# 41564749                                SmugMug
# 78179073                       Microformats.org
# 35097510                               NWsource
# 71235716                             Photo Matt
# 88771059                            TripAdvisor
# 43271453                   TanTek: CSS Examples
# 42457342                             Stopdesign
# 9426850                           Accessify.com
# 35085914                                    Nvu
# 26383877                                  Amber
# 76385983  Sillyness Spelled Wrong Intentionally
# 14650093                                myRadio
# 34596735                            Finck, Nick
# 77306602                                Glazman
# 32512987                              MetaGrrrl
# 74007274                              Netsensei
# 341785                           Perforación #1
# 36973698              Pixelcharmer: Field Notes
# 33611841                              Mullenweg
#
#                                                 Description
# 77324560  XHTML Friends Network hyperlink protocol for b...
# 2532360   Tony Buzan, l'inventeur de la méthode, présent...
# 24402307  Lets weblogs and similar sites display user-pr...
# 61412448              Consultant formateur en informatique.
# 42264752  Detailed visitor statistics and a choice of gr...
# 42124715  Focus on writing weblog entries and publishing...
# 47938851    Online survey, form and poll building software.
# 14906471  Offers software products for golf clubs. Inclu...
# 43485988  Real-time search for user-generated media (inc...
# 78353324  "NAI is a group of third party network adverti...
# 17933220  Provides information about the course, events,...
# 41564749  Fee-based online photo albums for easy photo s...
# 78179073  The official microformats site. Contains the d...
# 35097510  Events, movies, restaurants, shopping, music, ...
# 71235716  Covering advanced web development, PHP, web st...
# 88771059  Includes over 11,700 topics, 15,500 reviews an...
# 43271453  Reconstruction of artwork and layouts of non-m...
# 42457342  Multi-capability design firm specializing in c...
# 9426850   Tools, links and resources on Website accessib...
# 35085914  Open source web authoring system with WYSIWYG ...
# 26383877  Official site for San Francisco Bay Area's DJ ...
# 76385983     Chris J. Davis talks about life and computers.
# 14650093  Extension to Radio Userland aggregation from R...
# 34596735       Offers design, print, and graphics services.
# 77306602  Les billets de Daniel Glazman sur ses travaux ...
# 32512987  Dinah Sanders' thoughts on news, life, web des...
# 74007274  Ditjes en datjes van een Belgische. Frequent b...
# 341785              Un pequeño agujero en un lugar inusual.
# 36973698  Pointers to stuff Tanya Rabourn finds interest...
# 33611841  Family history including tree, photographs, ti...

# %%
a = np.where(cleaned_df["ID"] == 21860195) 69309242
a
# Out:
# (array([481025, 481026, 481027, 481028, 481029, 481030, 481031, 481032,
#         481033, 481034, 481035, 481036, 481037, 481038, 481039]),)

# %%
b = cleaned_df.iloc[481025]["Content"]
b
# Out:
# "['comic', 'kings', 'a', 'virginia', 'beach', 'virginia', 'retailer', 'selling', 'comic', 'books', 'and', 'other', 'pop', 'culture', 'merchandise', 'new', 'hampshire', 'potter', 's', 'guild', 'membership', 'information', 'upcoming', 'workshops', 'and', 'events', 'newsletters', 'and', 'officers', 'and', 'bylaws', 'ventura', 'county', 'potters', 'guild', 'a', 'non-profit', 'organization', 'promoting', 'ceramic', 'art', 'and', 'crafts', 'in', 'the', 'community', 'member', 's', 'gallery', 'and', 'ceramic', 'links', 'california', 'north', 'carolina', 'society', 'of', 'goldsmiths', 'non-profit', 'organization', 'supporting', 'north', 'carolina', 'area', 'metalsmiths', 'zeck', 'dana', 'a', 'weaver', 'in', 'south', 'new', 'jersey', 'includes', 'background', 'upcoming', 'shows', 'and', 'shops', 'where', 'items', 'can', 'be', '
# %%
# get_queried_rank("affirmative action")
9.444376e-08
# Out:
# 0          5.838182e-11
# 1          5.152582e-09
# 2          6.753812e-10
# 3          2.455216e-12
# 4          1.016845e-09
#                ...
# 2089095    1.199981e-10
# 2089096    1.600247e-10
# 2089097    8.142133e-10
# 2089098    2.002359e-10
# 2089099    1.110345e-09
# Length: 2089100, dtype: float64

# %%
queried_tspr = {}
queries = ["affirmative action", "alcoholism", "amusement parks", "architecture", "bicycling", "blues", 
           "cheese", "citrus groves", "classical guitar", "computer vision", "cruises", 
           "death valley", "field hockey", "gardening", "graphic design", "gulf war", "hiv", 
           "java", "lipari", "lyme disease", "mutual funds", "national parks", 
           "parallel architecture", "recycling cans", "rock climbing", "san francisco", "shakespeare", 
           "stamp collecting", "sushi", "table tennis", "telecommuting", "vintage cars", "volcano", 
           "zen buddhism", "zener"]

# %%
for query in queries:
    queried_tspr[query] = get_queried_rank(query)

# %%
queried_tspr["alcoholism"]
# Out:
# 0          1.928142e-07
# 1          1.819529e-04
# 2          2.111412e-05
# 3          5.692279e-08
# 4          2.996200e-05
#                ...
# 2089095    4.029783e-06
# 2089096    4.772189e-06
# 2089097    2.444343e-06
# 2089098    3.068040e-06
# 2089099    1.139420e-05
# Length: 2089100, dtype: float64

# %%
test = term_vectors_df[term_vectors_df['Terms'].isin(["test", "me"])]
test
# Out:
#      Terms  Arts  Business  Computers  Games  Health  Home  News  Recreation  \
# 1064  test   130      1260        608     32     123   205     0         133
# 4046    me   438        58        566    105      50    15     4          43
#
#       Reference  Regional  Science  Shopping  Society  Sports  World
# 1064        142      1160      500       107      163      74    866
# 4046         18       293       19        71      139      21    520

# %%
test = test.drop(columns=['Terms'])

# %%
test
# Out:
#       Arts  Business  Computers  Games  Health  Home  News  Recreation  \
# 1064   130      1260        608     32     123   205     0         133
# 4046   438        58        566    105      50    15     4          43
#
#       Reference  Regional  Science  Shopping  Society  Sports  World
# 1064        142      1160      500       107      163      74    866
# 4046         18       293       19        71      139      21    520

# %%
vecs = test.prod() / (term_vector_totals ** len(query_rows))
vecs
# Out:
# Arts          7.515318e-09
# Business      6.176390e-09
# Computers     2.187292e-07
# Games         2.325670e-08
# Health        8.976221e-09
# Home          3.685100e-08
# News          0.000000e+00
# Recreation    3.820641e-09
# Reference     6.555416e-09
# Regional      1.323161e-09
# Science       6.969071e-09
# Shopping      8.050861e-09
# Society       2.461302e-09
# Sports        1.054670e-09
# World         1.302338e-09
# dtype: float64

# %%
1/15 * vecs
# Out:
# Arts          5.010212e-10
# Business      4.117593e-10
# Computers     1.458195e-08
# Games         1.550447e-09
# Health        5.984147e-10
# Home          2.456733e-09
# News          0.000000e+00
# Recreation    2.547094e-10
# Reference     4.370278e-10
# Regional      8.821076e-11
# Science       4.646047e-10
# Shopping      5.367241e-10
# Society       1.640868e-10
# Sports        7.031135e-11
# World         8.682252e-11
# dtype: float64
